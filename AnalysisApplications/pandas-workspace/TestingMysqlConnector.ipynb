# %%
import mysql.connector as mysql
import pandas as pd

conn=mysql.connect(host='localhost',port=int(3306),user='root',passwd='mysqlpass',db='sales')

df=pd.read_sql_query("SELECT * FROM salesperson ",conn)

print(df)
# Out:
#     id first_name  last_name               email_address            city  \
# 0    1       Jack     Powell     jpowell0@hplussport.com       Lynchburg
# 1    2      Emily     Garcia     egarcia1@hplussport.com      Manchester
# 2    3    Richard       Dean       rdean2@hplussport.com         Houston
# 3    4       Jane     Porter     jporter3@hplussport.com      Alexandria
# 4    5      Robin    Vasquez    rvasquez4@hplussport.com         El Paso
# 5    6    Douglas     Flores     dflores5@hplussport.com         Houston
# 6    7      Craig   Johnston   cjohnston6@hplussport.com      Las Cruces
# 7    8      Norma    Johnson    njohnson7@hplussport.com        Amarillo
# 8    9    Kathryn     Bishop     kbishop8@hplussport.com         Roanoke
# 9   10        Joe    Stewart    jstewart9@hplussport.com        Mesquite
# 10  11     Dennis      Price      dpricea@hplussport.com            Lynn
# 11  12      Jason       Reid       jreidb@hplussport.com         Garland
# ...
